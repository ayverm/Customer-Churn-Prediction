# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
df = pd.read_csv('/kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df = df.drop(columns=['RowNumber', 'CustomerId', 'Surname'])

# %%
df = pd.get_dummies(df, columns=['Geography', 'Gender'], drop_first=True)

# %%
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# 1                  1        112542.58       0                  0
# 2                  0        113931.57       1                  0
# 3                  0         93826.63       0                  0
# 4                  1         79084.10       0                  0
# ...              ...              ...     ...                ...
# 9995               0         96270.64       0                  0
# 9996               1        101699.77       0                  0
# 9997               1         42085.58       1                  0
# 9998               0         92888.52       1                  1
# 9999               0         38190.78       0                  0
#
#       Geography_Spain  Gender_Male
# 0                   0            0
# 1                   1            0
# 2                   0            0
# 3                   0            0
# 4                   1            0
# ...               ...          ...
# 9995                0            1
# 9996                0            1
# 9997                0            0
# 9998                0            1
# 9999                0            0
#
# [10000 rows x 12 columns]

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
scaled = StandardScaler()

X_train_scaled = scaled.fit_transform(X_train)
X_test_scaled = scaled.transform(X_test)

# %%
model = Sequential()

model.add(Dense(8,activation='relu',input_dim=11))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 96
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dense_2 (Dense)             (None, 6)                 54
#
#  dense_3 (Dense)             (None, 4)                 28
#
#  dense_4 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics='accuracy')

# %%
history = model.fit(X_train, y_train, epochs=90, batch_size=50, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/90
# 128/128 [==============================] - 6s 5ms/step - loss: 127.8877 - accuracy: 0.5634 - val_loss: 0.6802 - val_accuracy: 0.7969
# Epoch 2/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.6787 - accuracy: 0.7958 - val_loss: 0.6459 - val_accuracy: 0.7969
# Epoch 3/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.6441 - accuracy: 0.7958 - val_loss: 0.6181 - val_accuracy: 0.7969
# Epoch 4/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.6152 - accuracy: 0.7958 - val_loss: 0.5952 - val_accuracy: 0.7969
# Epoch 5/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5925 - accuracy: 0.7958 - val_loss: 0.5766 - val_accuracy: 0.7969
# Epoch 6/90
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5748 - accuracy: 0.7958 - val_loss: 0.5613 - val_accuracy: 0.7969
# Epoch 7/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5603 - accuracy: 0.7958 - val_loss: 0.5490 - val_accuracy: 0.7969
# Epoch 8/90
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5485 - accuracy: 0.7958 - val_loss: 0.5389 - val_accuracy: 0.7969
# Epoch 9/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5388 - accuracy: 0.7958 - val_loss: 0.5314 - val_accuracy: 0.7969
# Epoch 10/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5323 - accuracy: 0.7956 - val_loss: 0.5251 - val_accuracy: 0.7962
# Epoch 11/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5251 - accuracy: 0.7958 - val_loss: 0.5198 - val_accuracy: 0.7969
# Epoch 12/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5207 - accuracy: 0.7958 - val_loss: 0.5159 - val_accuracy: 0.7969
# Epoch 13/90
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5173 - accuracy: 0.7958 - val_loss: 0.5129 - val_accuracy: 0.7969
# Epoch 14/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5146 - accuracy: 0.7958 - val_loss: 0.5105 - val_accuracy: 0.7969
# Epoch 15/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5126 - accuracy: 0.7958 - val_loss: 0.5088 - val_accuracy: 0.7969
# Epoch 16/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5110 - accuracy: 0.7958 - val_loss: 0.5074 - val_accuracy: 0.7969
# Epoch 17/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5098 - accuracy: 0.7958 - val_loss: 0.5064 - val_accuracy: 0.7969
# Epoch 18/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5089 - accuracy: 0.7958 - val_loss: 0.5057 - val_accuracy: 0.7969
# Epoch 19/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5083 - accuracy: 0.7958 - val_loss: 0.5052 - val_accuracy: 0.7969
# Epoch 20/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5079 - accuracy: 0.7958 - val_loss: 0.5049 - val_accuracy: 0.7969
# Epoch 21/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5076 - accuracy: 0.7958 - val_loss: 0.5047 - val_accuracy: 0.7969
# Epoch 22/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5279 - accuracy: 0.7958 - val_loss: 0.5044 - val_accuracy: 0.7969
# Epoch 23/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5090 - accuracy: 0.7958 - val_loss: 0.5043 - val_accuracy: 0.7969
# Epoch 24/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5073 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 25/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5072 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 26/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5071 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 27/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 28/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 29/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5068 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 30/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 31/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5068 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 32/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5068 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 33/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5067 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 34/90
# 128/128 [==============================] - 1s 7ms/step - loss: 0.5067 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 35/90
# 128/128 [==============================] - 1s 6ms/step - loss: 0.5067 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 36/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5067 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 37/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5068 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 38/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5066 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 39/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5064 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 40/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5068 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 41/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5065 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 42/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5065 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 43/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5064 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 44/90
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5064 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 45/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5064 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 46/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5064 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 47/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5063 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 48/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5063 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 49/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5063 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 50/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5062 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 51/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5062 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 52/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5061 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 53/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5061 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 54/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5061 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 55/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5061 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 56/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5060 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 57/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5059 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 58/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5059 - accuracy: 0.7958 - val_loss: 0.5043 - val_accuracy: 0.7969
# Epoch 59/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5060 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 60/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5059 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 61/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 62/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 63/90
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 64/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 65/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 66/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 67/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 68/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 69/90
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 70/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 71/90
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 72/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 73/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5043 - val_accuracy: 0.7969
# Epoch 74/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5059 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 75/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 76/90
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 77/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 78/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 79/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 80/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 81/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 82/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.7958 - val_loss: 0.5042 - val_accuracy: 0.7969
# Epoch 83/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 84/90
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 85/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 86/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5056 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 87/90
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 88/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5040 - val_accuracy: 0.7969
# Epoch 89/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5056 - accuracy: 0.7958 - val_loss: 0.5041 - val_accuracy: 0.7969
# Epoch 90/90
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5057 - accuracy: 0.7958 - val_loss: 0.5043 - val_accuracy: 0.7969

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7975

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
